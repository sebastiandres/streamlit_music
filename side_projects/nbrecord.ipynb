# %% [markdown]
# # Record Audio in a Notebook
#
# 1. Install dependencies
#
# 2. Enable Widgets
#
# 3. Restart Jupyter
#
# 4. Hit record and break some windows

# %%
# !pip install torchaudio ipywebrtc
#!sudo apt update
#!sudo apt install ffmpeg
# !jupyter nbextension enable --py widgetsnbextension
# Out:
# Collecting torchaudio
#   Downloading torchaudio-2.6.0-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting ipywebrtc
#   Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl.metadata (825 bytes)
# Collecting torch==2.6.0 (from torchaudio)
#   Using cached torch-2.6.0-cp311-none-macosx_11_0_arm64.whl.metadata (28 kB)
# Requirement already satisfied: filelock in /Users/sebastiandres/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from torch==2.6.0->torchaudio) (3.9.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/sebastiandres/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from torch==2.6.0->torchaudio) (4.12.2)
# Requirement already satisfied: networkx in /Users/sebastiandres/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from torch==2.6.0->torchaudio) (3.2.1)
# Requirement already satisfied: jinja2 in /Users/sebastiandres/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from torch==2.6.0->torchaudio) (3.1.2)
# Collecting fsspec (from torch==2.6.0->torchaudio)
#   Using cached fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting sympy==1.13.1 (from torch==2.6.0->torchaudio)
#   Using cached sympy-1.13.1-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy==1.13.1->torch==2.6.0->torchaudio)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sebastiandres/.pyenv/versions/3.11.1/lib/python3.11/site-packages (from jinja2->torch==2.6.0->torchaudio) (2.1.3)
# Downloading torchaudio-2.6.0-cp311-cp311-macosx_11_0_arm64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 10.2 MB/s eta 0:00:00
# Using cached torch-2.6.0-cp311-none-macosx_11_0_arm64.whl (66.5 MB)
# Using cached sympy-1.13.1-py3-none-any.whl (6.2 MB)
# Downloading ipywebrtc-0.6.0-py2.py3-none-any.whl (260 kB)
# Using cached fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, ipywebrtc, sympy, fsspec, torch, torchaudio
# Successfully installed fsspec-2025.3.0 ipywebrtc-0.6.0 mpmath-1.3.0 sympy-1.13.1 torch-2.6.0 torchaudio-2.6.0
# Enabling notebook extension jupyter-js-widgets/extension...
#       - Validating: OK

# %%
from ipywebrtc import AudioRecorder, CameraStream
camera = CameraStream(constraints={'audio': True,'video':False})
recorder = AudioRecorder(stream=camera)
recorder
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'audio': True, 'video': …

# %%
# Out:
# AudioRecorder(audio=Audio(value=b'', format='webm'), stream=CameraStream(constraints={'audio': True, 'video': …

# %%
import torchaudio
from IPython.display import Audio
with open('recording.webm', 'wb') as f:
    f.write(recorder.audio.value)
# !ffmpeg -i recording.webm -ac 1 -f wav file.wav -y -hide_banner -loglevel panic
sig, sr = torchaudio.load("file.wav")
print(sig.shape)
Audio(data=sig, rate=sr)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 4
#       2     f.write(recorder.audio.value)
#       3 get_ipython().system('ffmpeg -i recording.webm -ac 1 -f wav file.wav -y -hide_banner -loglevel panic')
# ----> 4 sig, sr = torchaudio.load("file.wav")
#       5 print(sig.shape)
#       6 Audio(data=sig, rate=sr)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/torchaudio/_backend/utils.py:204, in get_load_func.<locals>.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     118 def load(
#     119     uri: Union[BinaryIO, str, os.PathLike],
#     120     frame_offset: int = 0,
#    (...)
#     126     backend: Optional[str] = None,
#     127 ) -> Tuple[torch.Tensor, int]:
#     128     """Load audio data from source.
#     129
#     130     By default (``normalize=True``, ``channels_first=True``), this function returns Tensor with
#    (...)
#     202             `[channel, time]` else `[time, channel]`.
#     203     """
# --> 204     backend = dispatcher(uri, format, backend)
#     205     return backend.load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size)
#
# File ~/.pyenv/versions/3.11.1/lib/python3.11/site-packages/torchaudio/_backend/utils.py:116, in get_load_func.<locals>.dispatcher(uri, format, backend_name)
#     114     if backend.can_decode(uri, format):
#     115         return backend
# --> 116 raise RuntimeError(f"Couldn't find appropriate backend to handle uri {uri} and format {format}.")
#
# RuntimeError: Couldn't find appropriate backend to handle uri file.wav and format None.
